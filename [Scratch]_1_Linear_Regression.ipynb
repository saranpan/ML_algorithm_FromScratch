# %% [markdown]
# <a href="https://colab.research.google.com/github/wallik2/ML_algorithm_FromScratch/blob/main/%5BScratch%5D_1_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression From scratch 📏

# %% [markdown]
# ![](https://miro.medium.com/max/381/1*6Nl0idJQt4a1t4-jN3t9Jw.png)

# %% [markdown]
#  ⬇ Watch this if you think Linear Regression is useless 😠

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://www.youtube.com/watch?v=eL5UqGGz9oA&t=5s"><img src="https://icons.iconarchive.com/icons/dakirby309/windows-8-metro/32/Web-Youtube-alt-2-Metro-icon.png"/>View Here<
#   </td>

# %% [markdown]
# ---

# %% [markdown]
# <fieldset>
#
# **Explanation: We find b0, b1, b2 according the following formula from whole dataset**

# %% [markdown]
# <details>
#   <summary><b> Formula </b></summary>
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Given the below dataset

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assume the following data are satisfied with 4 assumptions

# %% [markdown]
# ---

# %% [markdown]
# ## Create Dataset

# %%
## from scratch
import numpy as np
x_1 = np.array([[10], [9], [6], [4]])
x_2 = np.array([[5], [7], [8], [9]])
Y = np.array([ 4,  6,  9, 10 ])

# %% [markdown]
# ## Linear Regression Algorithm

# %%
# mean of our inputs and outputs
x1_mean = np.mean(x_1); x2_mean = np.mean(x_2)
y_mean = np.mean(Y)

# %%
#total number of values
n = len(x_1)

# %%
# using the formula to calculate the b1 and b0
x1,x2,y,x11,x22,x12,x1y,x2y = 0,0,0,0,0,0,0,0

for i in range(n):
  y += Y[i]
  x1 += x_1[i]
  x2 += x_2[i]
  x11 += x_1[i]**2
  x22 += x_2[i]**2
  x12 += x_1[i]*x_2[i]
  x1y += x_1[i]*Y[i]
  x2y += x_2[i]*Y[i]

b1 = (( (x22 - (x2*x2/n))*(x1y - (x1*y/n)) )-( (x12 - (x1*x2/n)) * (x2y - (x2*y/n)) )) / ( (x11 - (x1*x1/n))*(x22 - (x2*x2/n)) - (x12 - (x1*x2/n))**2    )
b2 = (( (x11 - (x1*x1/n))*(x2y - (x2*y/n)) )-( (x12 - (x1*x2/n)) * (x1y - (x1*y/n)) )) / ( (x11 - (x1*x1/n))*(x22 - (x2*x2/n)) - (x12 - (x1*x2/n))**2    )
b0 = y_mean - (b1 * x1_mean) - (b2 * x2_mean) #printing the coefficient

print(f'coefficient: ( b1:{b1}, b2:{b2}) \nintercept (b0:{b0})')
# Out:
# coefficient: ( b1:[-0.53191489], b2:[0.76595745])
# intercept (b0:[5.55319149])

# %% [markdown]
# ---
